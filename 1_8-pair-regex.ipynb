# %% [markdown]
# Pair Expresiones regulares
# Validar un número de teléfono.
#
# Descripción: Verificar si una cadena representa un número de teléfono válido en el formato (XXX) XXX-XXXX.
#
# Probad para cada uno de los teléfonos que tenemos en la siguiente lista:
#
#
# Copy
# telefonos = ["(123) 456-7890", "178 1890-733", "(555) 238-1987", "(123) 4560-7890", "(ABC) 098-1111"]

# %%
import re

# %%
patron = r'^\(\d{3}\) \d{3}-\d{4}'

telefonos = ["(123) 456-7890", "178 1890-733", "(555) 238-1987", "(123) 4560-7890", "(ABC) 098-1111"]

for i in telefonos:
    resultado_numero = re.match(patron,i)
    if resultado_numero:
        print(f'El {i} es un número válido')
    else:
        print(f'El {i} no es un número válido')
# Out:
# El (123) 456-7890 es un número válido
# El 178 1890-733 no es un número válido
# El (555) 238-1987 es un número válido
# El (123) 4560-7890 no es un número válido
# El (ABC) 098-1111 no es un número válido

# %% [markdown]
# Buscar todas las direcciones de correo electrónico en un texto.
#
# Descripción: Encontrar todas las direcciones de correo electrónico presentes en una cadena de texto.
#
# Probad con el siguiente string:
#
#
# Copy
# texto = "Mi correo es user@example.com. Contacta conmigo en john.doe@email.com"

# %%
patron_correo = r'[.\d\w]+@[\d\w]+\.[\w]'

texto = "Mi correo es user@example.com. Contacta conmigo en john.doe@email.com"

resultado_mail = re.findall(patron_correo, texto)
print(resultado_mail)
# Out:
# []

# %% [markdown]
# Validar un código postal.
#
# Descripción: Verificar si una cadena representa un código postal válido de 5 dígitos.
#
# Probad para cada uno de los códigos postales que tenemos en la siguiente lista:
#
#
# Copy
# codigos_postales = ["12345", "190037", "78409", "986449", "19305"]

# %%
patron_cp = r'\d{5}$'

codigos_postales = ["12345", "190037", "78409", "986449", "19305"]

for i in codigos_postales:
    resultado_cp = re.match(patron_cp,i)
    if resultado_cp:
        print ('código válido')
    else:
        print('código no válido')
# Out:
# código válido
# código no válido
# código válido
# código no válido
# código válido
