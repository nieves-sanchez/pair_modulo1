# %% [markdown]
# Crear un conjunto vacío
#
# Descripción: Crea un conjunto vacío sin ningún elemento.

# %%
conjunto_vacío = {}

# %% [markdown]
# Crear un conjunto con elementos
#
# Descripción: Crea un conjunto con elementos predefinidos.

# %%
verduras = {"pimiento", "berenjena", "coliflor", "brocoli"}
verduras
# Out:
# {'berenjena', 'brocoli', 'coliflor', 'pimiento'}

# %% [markdown]
# Agregar elementos a un conjunto
#
# Descripción: Usando el set creado en el ejercicio 2, agrega nuevos elementos. Debereis agregar por separado:
#
# Un elemento solo
#
# Un par de elementos a la vez.

# %%
verduras.add("patata")
verduras
# Out:
# {'berenjena', 'brocoli', 'coliflor', 'patata', 'pimiento'}

# %%
verduras.update(["pepino", "tomate"])
verduras
# Out:
# {'berenjena', 'brocoli', 'coliflor', 'patata', 'pepino', 'pimiento', 'tomate'}

# %% [markdown]
# Eliminar un elemento de un conjunto
#
# Descripción: Usando el set creado en el ejercicio 2, elimina un elemento especificado por el usuario.

# %%
verduras.remove("pepino")
verduras
# Out:
# {'berenjena', 'brocoli', 'coliflor', 'patata', 'pimiento', 'tomate'}
